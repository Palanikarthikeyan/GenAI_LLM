# %%
Retrieval Aumument Generation (RAG) - pipeline

[ Documents 
   load     ]   --> [ chunks ] --> [ Embedding ] -> [ VectorDB - index ] 
  STEP1                STEP2          .......               ...

load env variables ->  .env 
                         |->OPENAI_API_KEY openAI 
                         |->..langchain
                         |->project
install langchain_openai module
               |->OpenAIEmbedding
                  .....
Apply Embedding 
|
Store to Vector DB 
    |->install langchain_community.vectorstores 

# Retrieve the results from query vectorstore db
#

# %%
# Embedding Techniques - Converting text into vectors
import os
os.environ # To see the existing env variables
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\theeba\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'DESKTOP-0OHV0KD',
#         'COMSPEC': 'C:\\Windows\\system32\\cmd.exe',
#         'CONDA_PREFIX': 'C:\\Users\\theeba\\anaconda3',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EFC_11344': '1',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\theeba',
#         'IGCCSVC_DB': '...',
#         'IPY_INTERRUPT_EVENT': '4376',
#         'JPY_INTERRUPT_EVENT': '4376',
#         'JPY_PARENT_PID': '4604',
#         'JPY_SESSION_NAME': 'C:\\Users\\theeba\\Untitled16.ipynb',
#         'LOCALAPPDATA': 'C:\\Users\\theeba\\AppData\\Local',
#         'LOGONSERVER': '\\\\DESKTOP-0OHV0KD',
# ...

# %%
os.environ['HOMEDRIVE']
# Out:
# 'C:'

# %%
os.environ['OPENAI_API_KEY']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.environ['OPENAI_API_KEY']
#
# File ~\anaconda3\Lib\os.py:685, in _Environ.__getitem__(self, key)
#     682     value = self._data[self.encodekey(key)]
#     683 except KeyError:
#     684     # raise KeyError with the original key value
# --> 685     raise KeyError(key) from None
#     686 return self.decodevalue(value)
#
# KeyError: 'OPENAI_API_KEY'

# %%
os.getenv("OPENAI_API_KEY")

# %%
from dotenv import load_dotenv

# %%
load_dotenv() # load all the env variables - reading from .env file
# Out:
# True

# %%
# adding new data
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\theeba'

# %%
# load all the env variables
import os
from dotenv import load_dotenv
load_dotenv() 
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 from langchain_openai import OpenAIEmbeddings
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
# !pip install langchain_openai
# Out:
# ...
#    ---------------------------------------- 0.0/50.4 kB ? eta -:--:--
#    ---------------------------------------- 50.4/50.4 kB 1.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/389.5 kB ? eta -:--:--
#    ------------------- -------------------- 194.6/389.5 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 389.5/389.5 kB 4.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/883.8 kB ? eta -:--:--
#    -------------------- ------------------- 450.6/883.8 kB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  880.6/883.8 kB 9.3 MB/s eta 0:00:01
#    ---------------------------------------- 883.8/883.8 kB 7.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/202.8 kB ? eta -:--:--
#    --------------------------------------- 202.8/202.8 kB 12.8 MB/s eta 0:00:00
# ...

# %%
from langchain_openai import OpenAIEmbeddings

# %%
print(OpenAIEmbeddings)

# embedding_obj = EmbeddingClass(model=<modelName>)   constructor
# ----------------------------------------------------
# Out:
# <class 'langchain_openai.embeddings.base.OpenAIEmbeddings'>

# %%
OpenAIEmbeddings - To get list of models
https://platform.openai.com/docs/guides/embeddings/embedding-models

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x0000015213690CE0>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x0000015213692C00>, model='text-embedding-3-large', dimensions=None, deployment='text-embedding-ada-002', openai_api_version=None, openai_api_base=None, openai_api_type=None, openai_proxy=None, embedding_ctx_length=8191, openai_api_key=SecretStr('**********'), openai_organization=None, allowed_special=None, disallowed_special=None, chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None, http_async_client=None, check_embedding_ctx_length=True)

# %%
from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
# load the data ->chunk ->embedding ->storeVectorDB

# %%
from langchain_community.vectorstores import Chroma

# %%
# !pip install chromadb
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/67.3 kB ? eta -:--:--
#      ---------------------------------------- 67.3/67.3 kB 1.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached protobuf-5.28.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# ...

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("speech.txt")
docs = loader.load()

from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents =text_splitter.split_documents(docs)

# %%
embeddings_1024 = OpenAIEmbeddings(model="text-embedding-3-large",dimensions=1024)

# %%
import chromadb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 import chromadb
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
import sys
sys.path
v='C:\\Users\\theeba\\anaconda3\\Lib\\site-packages\\langchain_community\\vectorstores'
sys.path.append(v)

# %%
sys.path
# Out:
# ['C:\\Users\\theeba\\anaconda3\\python312.zip',
#  'C:\\Users\\theeba\\anaconda3\\DLLs',
#  'C:\\Users\\theeba\\anaconda3\\Lib',
#  'C:\\Users\\theeba\\anaconda3',
#  '',
#  'C:\\Users\\theeba\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\theeba\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\theeba\\anaconda3\\Lib\\site-packages\\win32\\lib',
#  'C:\\Users\\theeba\\anaconda3\\Lib\\site-packages\\Pythonwin',
#  'C:\\Users\\theeba\\anaconda3\\Lib\\site-packages\\langchain_community\\vectorstores']

# %%
import chromadb
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 import chromadb
#
# ModuleNotFoundError: No module named 'chromadb'

# %%
# vector embedding and vector storeDB
from langchain_community.vectorstores import Chroma
db = Chroma.from_documents(final_documents,embeddings)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\langchain_community\vectorstores\chroma.py:83, in Chroma.__init__(self, collection_name, embedding_function, persist_directory, client_settings, collection_metadata, client, relevance_score_fn)
#      82 try:
# ---> 83     import chromadb
#      84     import chromadb.config
#
# ModuleNotFoundError: No module named 'chromadb'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[83], line 3
#       1 # vector embedding and vector storeDB
#       2 from langchain_community.vectorstores import Chroma
# ----> 3 db = Chroma.from_documents(final_documents,embeddings)
#
# ...

# %%
## Retrieve the results from query vectorstoredb
query="It will be all the easier for us to conduct ourselves as belligerents"
retrieved_results = db.similarity_search(query)
print(retrieved_results)

# %%
from langchain_community.embeddings import OllamaEmbeddings

# %%
OllamaEmbeddings(model="gemma:2")
# Out:
# C:\Users\theeba\AppData\Local\Temp\ipykernel_49620\285329614.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaEmbeddings``.
#   OllamaEmbeddings(model="gemma:2")
# OllamaEmbeddings(base_url='http://localhost:11434', model='gemma:2', embed_instruction='passage: ', query_instruction='query: ', mirostat=None, mirostat_eta=None, mirostat_tau=None, num_ctx=None, num_gpu=None, num_thread=None, repeat_last_n=None, repeat_penalty=None, temperature=None, stop=None, tfs_z=None, top_k=None, top_p=None, show_progress=False, headers=None, model_kwargs=None)

# %%
embeddings = OllamaEmbeddings(model="gemma:2b")

text = "Hello world example"

embeddings.embed_query(text)
# Out:
# [-0.43313735723495483,
#  -0.5817371606826782,
#  -1.2361633777618408,
#  1.4634532928466797,
#  0.9374618530273438,
#  -0.8238786458969116,
#  -0.18493624031543732,
#  0.1207735612988472,
#  3.1484365463256836,
#  -2.136705160140991,
#  0.7113842964172363,
#  0.3693704903125763,
#  0.5779675841331482,
#  0.16422013938426971,
#  1.0324499607086182,
#  1.0045838356018066,
#  3.413623332977295,
#  -0.3941343128681183,
#  -0.12042900174856186,
#  0.6084696650505066,
#  -0.3408967852592468,
#  -0.38997212052345276,
#  -1.2649569511413574,
#  -0.16129715740680695,
#  -1.1134281158447266,
#  -0.05857476964592934,
#  -0.3899458050727844,
#  -0.6818179488182068,
#  1.406106948852539,
#  -2.159480333328247,
#  0.6971903443336487,
#  0.4855029582977295,
#  0.37021157145500183,
#  -0.2920331656932831,
#  0.41738206148147583,
#  0.31556907296180725,
#  0.11268435418605804,
#  -1.1928201913833618,
#  0.10494725406169891,
#  -1.3248392343521118,
#  2.2808756828308105,
#  -1.399570345878601,
# ...

# %%
doc = embeddings.embed_documents(["abc is the first word","xyz is the last word"])
doc
# Out:
# [[-1.8270816802978516,
#   -0.4577339291572571,
#   -1.18026602268219,
#   2.455021858215332,
#   0.9538295269012451,
#   0.6677517890930176,
#   -1.5365570783615112,
#   0.9338785409927368,
#   1.418061375617981,
#   -1.2359473705291748,
#   1.8288657665252686,
#   0.6762527823448181,
#   0.7577236890792847,
#   0.5032703280448914,
#   0.3384522497653961,
#   1.4269641637802124,
#   1.1140239238739014,
#   -0.13315176963806152,
#   1.7311506271362305,
#   0.33352068066596985,
#   -0.021958187222480774,
#   -1.5597847700119019,
#   0.762517511844635,
#   -1.0103189945220947,
#   -0.991580605506897,
#   -0.44792765378952026,
#   -0.8828091025352478,
#   1.230111002922058,
#   0.06733031570911407,
#   0.6000815033912659,
#   0.43406403064727783,
#   -0.21194098889827728,
#   1.1799771785736084,
#   -0.08574452251195908,
#   1.8679429292678833,
#   -0.038520343601703644,
#   -0.16174887120723724,
#   0.365932434797287,
#   0.015231329016387463,
#   -1.6030395030975342,
# ...

# %%
doc[0]
# Out:
# [-1.8270816802978516,
#  -0.4577339291572571,
#  -1.18026602268219,
#  2.455021858215332,
#  0.9538295269012451,
#  0.6677517890930176,
#  -1.5365570783615112,
#  0.9338785409927368,
#  1.418061375617981,
#  -1.2359473705291748,
#  1.8288657665252686,
#  0.6762527823448181,
#  0.7577236890792847,
#  0.5032703280448914,
#  0.3384522497653961,
#  1.4269641637802124,
#  1.1140239238739014,
#  -0.13315176963806152,
#  1.7311506271362305,
#  0.33352068066596985,
#  -0.021958187222480774,
#  -1.5597847700119019,
#  0.762517511844635,
#  -1.0103189945220947,
#  -0.991580605506897,
#  -0.44792765378952026,
#  -0.8828091025352478,
#  1.230111002922058,
#  0.06733031570911407,
#  0.6000815033912659,
#  0.43406403064727783,
#  -0.21194098889827728,
#  1.1799771785736084,
#  -0.08574452251195908,
#  1.8679429292678833,
#  -0.038520343601703644,
#  -0.16174887120723724,
#  0.365932434797287,
#  0.015231329016387463,
#  -1.6030395030975342,
#  2.3347091674804688,
#  -0.556856095790863,
# ...

# %%
embeddings.embed_query("what is the last word")
# Out:
# [-0.8166189789772034,
#  -0.4227128028869629,
#  -1.551279902458191,
#  1.7517350912094116,
#  2.737314224243164,
#  -0.0517142079770565,
#  -2.4700183868408203,
#  0.7613508105278015,
#  1.0171278715133667,
#  -1.7082926034927368,
#  1.424088478088379,
#  0.1712523251771927,
#  -0.2063797265291214,
#  -0.6708638072013855,
#  -0.7106555104255676,
#  0.00813053548336029,
#  4.300843715667725,
#  0.18136614561080933,
#  0.49829351902008057,
#  0.1307983100414276,
#  -1.3048065900802612,
#  0.42414700984954834,
#  0.22237102687358856,
#  -1.8265204429626465,
#  -1.3063758611679077,
#  -0.39661940932273865,
#  -0.7598662376403809,
#  1.383174180984497,
#  1.688165307044983,
#  0.41913464665412903,
#  0.741169273853302,
#  0.7009450793266296,
#  1.9486825466156006,
#  -0.8081304430961609,
#  -0.1545642465353012,
#  -0.3029276728630066,
#  1.4842872619628906,
#  0.3791202902793884,
#  0.9069823026657104,
#  -2.319476842880249,
#  1.3525428771972656,
#  0.2987532913684845,
# ...

# %%
r = embeddings.embed_query("what is the last word")
r[1]
# Out:
# -0.4227128028869629

# %%
len(doc[1])
# Out:
# 2048

# %%
# !pip install langchain_ollama

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_ollama.embeddings import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
loader = TextLoader('speech.txt')
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000,chunk_overlap=30)
docs = text_splitter.split_documents(documents)

# %%
# !pip install faiss-cpu
# Out:
# ...
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.8 MB 325.1 kB/s eta 0:00:43
#    ---------------------------------------- 0.1/13.8 MB 558.5 kB/s eta 0:00:25
#    - -------------------------------------- 0.5/13.8 MB 2.7 MB/s eta 0:00:05
#    -- ------------------------------------- 0.9/13.8 MB 4.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.4/13.8 MB 5.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.8/13.8 MB 6.1 MB/s eta 0:00:02
#    ------ --------------------------------- 2.1/13.8 MB 6.0 MB/s eta 0:00:02
#    ------- -------------------------------- 2.7/13.8 MB 6.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.2/13.8 MB 7.1 MB/s eta 0:00:02
#    --------- ------------------------------ 3.2/13.8 MB 7.1 MB/s eta 0:00:02
# ...

# %%
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='The world must be made safe for democracy. Its peace must be planted upon the tested foundations of political liberty. We have no selfish ends to serve. We desire no conquest, no dominion. We seek no indemnities for ourselves, no material compensation for the sacrifices we shall freely make. We are but one of the champions of the rights of mankind. We shall be satisfied when those rights have been made as secure as the faith and the freedom of nations can make them.\n\nJust because we fight without rancor and without selfish object, seeking nothing for ourselves but what we shall wish to share with all free peoples, we shall, I feel confident, conduct our operations as belligerents without passion and ourselves observe with proud punctilio the principles of right and of fair play we profess to be fighting for.\n\nâ€¦'),
# ...

# %%
embeddings = OllamaEmbeddings(model="gemma:2b")

# %%
#db = FAISS.from_documents(docs,embeddings)

# %%
# create a query
query = "How to describe the war?"

docs = db.similarity_search(query)
print(len(docs))
print(docs[0]))
print(docs[0].page_content)

# %%
#help(FAISS.load_local)
# Out:
# Help on method load_local in module langchain_community.vectorstores.faiss:
#
# load_local(folder_path: 'str', embeddings: 'Embeddings', index_name: 'str' = 'index', *, allow_dangerous_deserialization: 'bool' = False, **kwargs: 'Any') -> 'FAISS' class method of langchain_community.vectorstores.faiss.FAISS
#     Load FAISS index, docstore, and index_to_docstore_id from disk.
#
#     Args:
#         folder_path: folder path to load index, docstore,
#             and index_to_docstore_id from.
#         embeddings: Embeddings to use when generating queries
#         index_name: for saving with a specific index file name
#         allow_dangerous_deserialization: whether to allow deserialization
#             of the data which involves loading a pickle file.
#             Pickle files can be modified by malicious actors to deliver a
#             malicious payload that results in execution of
#             arbitrary code on your machine.

# %%
# Embedding Techniques using HuggingFace
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
os.environ['HF_TOKEN'] = os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[157], line 1
# ----> 1 from langchain_huggingface import HuggingFaceEmbeddings
#
# ModuleNotFoundError: No module named 'langchain_huggingface'

# %%
# !pip install langchain_huggingface
# Out:
# ...
#   Using cached huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached sentence_transformers-3.3.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl.metadata (6.9 kB)
# ...
#   Using cached transformers-4.46.3-py3-none-any.whl.metadata (44 kB)
# ...
# Using cached huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
# ...
#    ---------------------------------------- 0.0/268.8 kB ? eta -:--:--
#    --------------------- ------------------ 143.4/268.8 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 268.8/268.8 kB 3.3 MB/s eta 0:00:00
# Using cached tokenizers-0.20.3-cp312-none-win_amd64.whl (2.4 MB)
# ...
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    - -------------------------------------- 0.4/10.0 MB 12.2 MB/s eta 0:00:01
#    -- ------------------------------------- 0.7/10.0 MB 9.5 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.1/10.0 MB 10.4 MB/s eta 0:00:01
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# model.safetensors:  81%|########  | 73.4M/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
embeddings
# Out:
# HuggingFaceEmbeddings(model_name='all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
text = "Hello world"
query_result = embeddings.embed_query(text)
query_result
# Out:
# [-0.03447727486491203,
#  0.03102312609553337,
#  0.006734980270266533,
#  0.026108933612704277,
#  -0.03936205804347992,
#  -0.16030246019363403,
#  0.06692394614219666,
#  -0.006441438104957342,
#  -0.047450482845306396,
#  0.014758863486349583,
#  0.07087534666061401,
#  0.05552757531404495,
#  0.019193356856703758,
#  -0.02625126577913761,
#  -0.01010954286903143,
#  -0.026940442621707916,
#  0.022307462990283966,
#  -0.02222665585577488,
#  -0.14969263970851898,
#  -0.017493024468421936,
#  0.007676282897591591,
#  0.054352231323719025,
#  0.0032544038258492947,
#  0.03172588348388672,
#  -0.08462139964103699,
#  -0.029405992478132248,
#  0.051595550030469894,
#  0.048124078661203384,
#  -0.003314835485070944,
#  -0.05827915295958519,
#  0.04196925833821297,
#  0.022210702300071716,
#  0.1281888633966446,
#  -0.022338951006531715,
#  -0.011656239628791809,
#  0.06292837113142014,
#  -0.03287634998559952,
#  -0.09122604131698608,
#  -0.03117534890770912,
#  0.052699536085128784,
# ...
